# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data (x: features, y: target)
x = np.array([1, 2, 3, 4, 5])
y = np.array([3, 4, 2, 5, 6])

# Function to calculate mean squared error
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# Step 1: Estimate coefficients (slope m and intercept c)
def estimate_coefficients(x, y):
    n = len(x)
    mean_x = np.mean(x)
    mean_y = np.mean(y)

    #diversion of x and y
    div_x=(x-mean_x)
    div_y=(y-mean_y)
    # slope (m)
    m = np.sum((div_x) * (div_y)) / np.sum((div_x)**2)
    
    # intercept (c)
    c = mean_y - m * mean_x
    
    return m, c

# Step 2: Predict values
def predict(x, m, c):
    return m * x + c

# Step 3: Train
m, c = estimate_coefficients(x, y)
print(f"Slope (m): {m}")
print(f"Intercept (c): {c}")

# Step 4: Predict values
y_pred = predict(x, m, c)

# Step 5: Evaluate
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse}")

# Plotting
plt.scatter(x, y, color="blue", label="Actual")
plt.plot(x, y_pred, color="red", label="Predicted Line")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Linear Regression from Scratch")
plt.show()
# Out:
# Slope (m): 0.7
# Intercept (c): 1.9000000000000004
# Mean Squared Error: 1.0199999999999998
